# %% [markdown]
# # Selenium for 경제_무역뉴스

# %% [markdown]
# ### Import Files

# %%
import sqlite3 as sq3
from pandas.io import sql
import os
import re
import string
import csv
import pandas as pd
from tabulate import tabulate
import time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import requests
import lxml.html
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager

import pyperclip  # 클립보드 기능

# %% [markdown]
# ## get_each_page()
# - gets to each page

# %%
def get_each_page():
    article_details = []

    driver.get('https://dream.kotra.or.kr/dream/cms/com/index.do?MENU_ID=2370#;')
    click_the_first_link  = driver.find_element('xpath','//*[@id="tbody"]/tr[1]/td[2]/a').click()
    driver.implicitly_wait(8)

    while(True):
        title = driver.find_element('xpath','//*[@id="pdfArea"]/dl/dt/div[1]/h2').text
        print(title)
        article_details.append(get_info())
        try:
            p = driver.find_element('xpath','//*[@class="no_article"]').text
            # click previous button onless the article is the last one
            if (p == "이전글이 없습니다."):
                break
        except Exception:
            driver.implicitly_wait(1)
        click_prev = driver.find_element('xpath','//*[@id="contents"]/article/div/div[3]/ul/li[1]/p/a').click()
    return article_details

# %% [markdown]
# ## remove_punc()
# - removes punctuations from string

# %%
def remove_punc(data):

    punc = '[!"#$%&\'()*+,-./:;<=>?[\]^_`{|}~“”·「」△◈《》•◦ㅇ‘’中■○□※▷①②③④【】『∙』·-“”▲I]'
    new_string = re.sub(punc, '', data) # 특수문자 제거
    new_string2 = re.sub('\n', ' ', new_string) # newline 제거
    new_string3 = re.sub('\\s+', ' ', new_string2) # multiple spaces 제거
    return new_string3

# %% [markdown]
# ## db_save()
# - saves data as db file

# %%
def db_save(ARTICLE_LIST,db_name,table_name):
    with sq3.connect(os.path.join('.',db_name)) as con: # sqlite DB 파일이 존재하지 않는 경우 파일생성
        try:
            ARTICLE_LIST.to_sql(name = table_name, con = con, index = False, if_exists='replace') 
            #if_exists : {'fail', 'replace', 'append'} default : fail
        except Exception as e:
            print(str(e))
        print(len(ARTICLE_LIST), '건 저장완료..')

# %%
def db_select(db_name, table_name):
    with sq3.connect(db_name) as con: 
        try:
            query = 'SELECT * FROM {}'.format(table_name)
            df = pd.read_sql(query, con = con)
        except Exception as e:
            print(str(e)) 
        return df

# %% [markdown]
# ## get_info()
# - returns detailed information on the article pages as list

# %%
def get_info():
    details = []
    article_s = []
    article_string = ""

    title = driver.find_element('xpath','//*[@id="pdfArea"]/dl/dt/div[1]/h2').text
    category = driver.find_element('xpath','//*[@id="pdfArea"]/dl/dt/div[2]/ul/li[1]/span').text
    country = driver.find_element('xpath','//*[@id="pdfArea"]/dl/dt/div[2]/ul/li[2]').text
    articles = driver.find_elements('xpath','//*[@class="viewDataWrap"]/p')
    for article in articles:
        article_s.append(article.text)
    article_string = " ".join(article_s)
    article_edited = remove_punc(article_string)
    
    details.append(title)
    details.append(category)
    details.append(country)
    details.append(article_edited)
    #details.append(get_pdf())
    
    return details

# %%
def get_pdf():
    # click download and wait
    articles = driver.find_element('xpath','//*[@id="pdfArea"]/dl/dd/div[1]/ul/li/a').click()
    article_title = driver.find_element('xpath','//*[@id="pdfArea"]/dl/dd/div[1]/ul/li/a').text
    driver.implicitly_wait(15)
    
    article_title2 = re.sub(' ','%20', article_title)
    article_title3 = 'file:///C:/Users/user/Downloads/'+ article_title2
    driver.get(article_title3)
    
    # action chain object creation
    a = ActionChains(driver)
    # perform the ctrl+c pressing action
    select_a = a.key_down(Keys.CONTROL).send_keys('A').perform()
    copy_a = a.key_down(Keys.CONTROL).send_keys('C').perform()
    articles = pyperclip.paste()
    print(articles)
    
    for eachstring in articles:
        article = ' '.join(eachstring.text)
    article = re.sub('  ', ' ', article)
    
    driver.implicitly_wait(4)
    
    words = remove_punc(article)
    driver.close()
    return words

# %% [markdown]
# ## db_save_as_csv()
# - saves dataframe as csv

# %%
def db_save_as_csv(data):
    data.to_csv("경제_무역.csv", index=False, encoding='utf-8')

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------------
# # Main
# This is the main part which uses functions to read articles and saves the data as csv file
# ### ---------------------------------------------------------------------------------------------------------------------

# %%
options = webdriver.ChromeOptions() 
#options.add_argument("--start-maximized");  # Chrome 브라우저 최대화 설정
options.add_argument('--headless')  # headless 모드
options.add_argument('--disable-gpu')  # 그래픽 가속 해제 (오류 방지)
#options.add_argument('--mute-audio')  # 음소거모드 적용

driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()), options = options)

driver.get('https://dream.kotra.or.kr/dream/cms/com/index.do?MENU_ID=2370')
driver.implicitly_wait(5)

df_list = []
details = get_each_page()

for each_det in details:
    df = pd.DataFrame([{
        "제목": each_det[0],
        "카테고리": each_det[1],
        "국가": each_det[2],
        "본문": each_det[3]
    }])
    df_list.append(df)
    driver.implicitly_wait(4)
    
ARTICLE_LIST = pd.concat(df_list)

db_save(ARTICLE_LIST,'경제_무역.db','경제_무역')
db_save_as_csv(ARTICLE_LIST)

driver.close()
driver.quit()
# Out:
# 숫자로 보는 세계 70개 항구 적체 현황 리포트(9월 호)
# 미국 국가 생명공학 및 바이오 제조 이니셔티브(9.12) 주요 내용
# [미국경제통상리포트(US22-32)]미국의 전기차 배터리용 핵심 광물 확보 전략
# [미국경제통상리포트(US22-31)] IPEF 9월 장관회의 세부 내용 및 현지 반응
# 인도 정부의 탄소배출 감축 계획과 우리기업 기회요인
# KOTRA IP-DESK 지식재산권 뉴스레터 7호(ASEAN+)
# 2022년 8월 글로벌 및 주요국 경제동향과 전망
# [2022.09.08] 글로벌 공급망 인사이트 27호
# 케냐 대선(8.9) 결과 및 향후 전망
# KOTRA IP-DESK 지식재산권 뉴스레터 6호(IP5+)
# 영국 총리 경선 결과 및 전망
# [미국경제통상리포트(US22-30)] 반도체 칩과 과학법 세부 내용 및 시사점
# [미국경제통상리포트(US22-29)] 미국 2분기 GDP 주요 지표 동향 및 시사점
# [미국경제통상리포트(US22-28)] 미국 6월 주택시장 동향 및 전망
# [미국경제통상리포트(US22-27)] 미리 보는 美 의회 중간선거 결과와 관전포인트
# [EU 경제통상 리포트(22-25)] EU 디지털 패키지(DMA&DSA) 입법 동향과 시사점
# [EU 경제통상리포트(22-24)] 유럽 물류시장 동향 및 업계 대안
# [EU 경제통상리포트(22-23)] 러시아-우크라 사태 관련 EU 정책 동향 및 전망
# 2022년 상반기 우리나라의 전자상거래 수출 동향
# [2022.09.01] 글로벌 공급망 인사이트 26호
# [2022.08.25] 글로벌 공급망 인사이트 25호
# KOTRA IP-DESK 지식재산권 뉴스레터 4호(IP5+), 5호(ASEAN+)
# [미국경제통상리포트(US22-26)] 미국 인플레이션 감축법 입법동향 및 주요내용
# 숫자로 보는 세계 70개 항구 적체 현황 리포트(8월 호)
# [2022.08.18] 글로벌 공급망 인사이트 24호
# [2022.08.11] 글로벌 공급망 인사이트 23호
# 2022년 7월 글로벌 및 주요국 경제동향과 전망
# 日, 경제안전보장법 기본지침(안)의 주요 내용과 평가
# [미국경제통상리포트(US22-25)]미국 고용시장 동향에 대한 현지 반응 및 시사점
# [미국경제통상리포트(US22-24)] 위구르 강제노동 방지법과 공급망 동향
# [미국경제통상리포트(US22-23)] 2021년 미국 신규 FDI 유치 통계 분석 및 시사점
# [미국경제통상리포트(US22-22)] 미국 리세션 가능성 분석 전망 및 대응 시사점
# 미국 7월 FOMC 회의 주요 결정사항 및 시장반응
# [2022.07.28] 글로벌 공급망 인사이트 22호
# [EU 경제통상 리포트(22-22)] EU, 녹색-디지털 전환 가속화 위한 10대 정책 영역 발표
# [EU 경제통상리포트(22-21)] EU 녹색수소 프로젝트 추진 가속화
# ECB 통화정책회의(7.21) 주요 결정사항 및 반응
# 이탈리아 마리오 드라기 총리 사임 관련 동향 및 전망
# [2022.07.21] 글로벌 공급망 인사이트 21호
# 숫자로 보는 세계 70개 항구 적체 현황 리포트(7월 호)
# 이탈리아 마리오 드라기 총리 사의 표명 관련 현지 동향
# [EU 경제통상리포트(22-20)] EU 역외보조금 규정 입법 동향
# [2022.07.14] 글로벌 공급망 인사이트 20호
# [일본 경제통상리포트 22-04] 러시아의 사할린2 변경 조치가 일본에 미치는 영향
# 영국 보리스 존슨 총리 보수당 대표 사임 관련 현지 동향
# 일본 참의원 선거 결과 및 전망
# 스리랑카 대통령 사임 발표(7.09.) 및 향후 전망
# 유럽의회, EU 녹색분류체계 위임입법 통과
# 2022년 6월 글로벌 및 주요국 경제동향과 전망
# [2022.07.07] 글로벌 공급망 인사이트 19호
# [중국 경제통상리포트 22-03] 최근 중국의 경제안정화 조치 분석 및 전망
# [일본 경제통상리포트 22-03] 일본 참의원 선거의 주요 쟁점 분석 및 전망
# [2022.06.30] 글로벌 공급망 인사이트 18호
# [EU 경제통상리포트(22-19)] 유럽의회, 기후대응법안 가결 및 CBAM 입법 진전
# [EU 경제통상리포트(22-18)] REPowerEU 정책 세부내용
# [미국 경제통상 리포트(US22-21)] 미 1분기 벤처투자 동향 및 현지 반응
# 러시아는 서방의 경제제재를 어떻게 대비했나?: 금융관점의 시각
# [2022.06.23] 글로벌 공급망 인사이트 17호
# [미국 경제통상 리포트(US22-20)] 제12차 WTO 각료회의를 앞둔 현지 반응
# 6월 미국 연준 FOMC 회의 주요 결정사항 및 시장 반응
# [2022.06.16] 글로벌 공급망 인사이트 16호
# 최근 식량안보 동향과 시사점
# [EU 경제통상 리포트(22-17)] EU 기후대응정책패키지(Fit for 55) 입법 동향
# 2022년 5월 글로벌 및 주요국 경제동향과 전망
# [EU 경제통상리포트(22-16)] EU, 러 원유 및 석유제품 수입 부분 금지 발표
# [2022.06.09] 글로벌 공급망 인사이트 15호
# [일본 경제통상리포트 22-02] 일본정부의 '새로운 자본주의 실행계획(안)' 발표
# [중국 경제통상 리포트(CHN22-2)] 재중 외국상회 설문조사 결과 및 시사점
# 콜롬비아 61대 대선 1차 투표결과 및 향후 전망
# [2022.06.01] 글로벌 공급망 인사이트 14호
# [중국 경제통상 리포트(CHN22-1)] 중국의 4월 수출입 실적 및 전망
# [EU 경제통상 리포트(EU22-15)] EU의 지속가능한 제품을 위한 에코디자인 규정
# 레바논 경제위기 관련 최근 동향 및 전망
# [미국 경제통상 리포트(US22-19)] 미-EU 무역기술위원회 회의 결과 및 현지 반응
# [미국 경제통상 리포트(US22-18)] 미국 인플레이션 동향 및 주요 대응정책
# [2022.05.26] 글로벌 공급망 인사이트 13호
# [EU 경제통상 리포트(EU22-14)] EU-미 무역기술위원회 2차 회의 주요내용
# [EU 경제통상 리포트(EU22-13)] 지속가능보고기준공개초안 주요내용
# [일본 경제통상 리포트] 일본 경제안전보장법의 주요 내용 및 쟁점 분석
# 한미 정상회담 공동성명(5.21) 주요 내용
# [2022.05.19] 글로벌 공급망 인사이트 12호
# 인도의 밀 수출금지 조치 발표(5.13.) 및 관련 영향
# 글로벌 그린 유니콘 정책 추진 동향 및 시사점
# 미국 경제통상 리포트(US22-17)] 미국 1분기 수출입 현황 분석
# [2022.05.12] 글로벌 공급망 인사이트 11호
# 미국 경제통상 리포트(US22-16)] 美 반덤핑.상계관세 제도 강화 입법 동향 및 현지 반응
# 5월 미국 연준 FOMC 회의 주요 결정사항 및 시장 반응
# 2022년 4월 글로벌 및 주요국 경제동향과 전망
# 미국 경제통상 리포트(US22-15)] 美 상하원 대중견제법 분석 및 시사점
# [2022.05.05] 글로벌 공급망 인사이트 10호
# 필리핀 대선 동향
# [2022.04.28] 글로벌 공급망 인사이트 9호
# 프랑스 대선 결과 및 전망
# 신남방지역 주요이슈리포트 (2022년 4월 28일)
# [미국 경제통상 리포트(US22-14)] 2023년 美 대통령 예산안 주요내용
# 이집트 경제위기 관련 최근 동향 및 수입제한 조치 개요
# 엔화 가치 20년만의 최저치 기록: 원인과 전망
# [2022.04.21] 글로벌 공급망 인사이트 8호
# 신남방지역 주요이슈리포트 (2022년 4월 21일)
# [미국 경제통상 리포트(US22-13)] 美 증권거래위원회 기후변화 위험성 공시안 주요내용
# 중국 지역별 코로나19 피해기업 지원정책 조사결과
# [2022.04.14] 글로벌 공급망 인사이트 7호
# 신남방지역 주요이슈리포트(2022년 4월 14일)
# 프랑스 대통령 선거 1차 투표 결과 및 향후 전망
# 스리랑카 디폴트 선언 관련 동향 및 향후 전망
# [EU 경제통상 리포트(EU22-12)] 기후클럽(Climate Club)논의현황
# 스리랑카 반정부 시위 및 디폴트 위기 관련 동향과 향후 전망
# 미얀마 달러화 계좌 강제 환전 조치 시행경과
# [미국 경제통상 리포트(US22-12)] 안정적 공급망 확보를 위한 바이든 행정부의 주요 정책
# 2022년 3월 글로벌 및 주요국 경제동향과 전망
# [2022.04.07] 글로벌 공급망 인사이트 6호
# 신남방지역 주요이슈리포트(2022년 4월 7일)
# [미국 경제통상 리포트(US22-11)] 美 USTR 타이 대표, 하원 청문회 결과 및 주요 정책 동향
# 글로벌 백신 공급망 및 수출 동향
# [미국 경제통상 리포트(US22-10)] 미-영 간 232조 철강 관세 면제 합의 결과 주요내용
# [2022.03.31] 글로벌 공급망 인사이트 5호
# [미국 경제통상 리포트(US22-9)] 美 외항해운개혁법 입법 추진 동향
# 신남방지역 주요이슈리포트(2022년 3월 30일)
# [EU 경제통상 리포트(EU22-11)] 바이든 美 대통령 참석 EU 정상회담(3.24~3.25) 개최결과
# [EU 경제통상 리포트(EU22-10)] EU 데이터법 추진현황과 시사점
# [미국 경제통상 리포트(US22-8)] 미국의 대러 경제제재 현황 종합 및 분석
# [2022.03.24] 글로벌 공급망 인사이트 4호
# [EU 경제통상 리포트(EU22-9)] EU 이사회, 탄소국경조정제도(CBAM) 합의안 주요 내용
# 신남방지역 주요 이슈리포트(2022년 3월 24일)
# [미국 경제통상 리포트(US22-7)] 美 2022년 무역정책 어젠다 주요내용
# 3월 미국 연준 FOMC 회의 주요 결정사항 및 시장 반응
# [EU 경제통상 리포트(EU22-8)] 우크라이나사태관련 EU 긴급 정상회담 개최 결과
# [2022.03.17] 글로벌 공급망 인사이트 3호
# 신남방지역 주요 이슈리포트(2022년 3월 17일)
# 2021년 아세안-5 경제실적과 수출입 동향
# 주요국 경제활동 재개(리오프닝) 추진 동향 및 전망
# 중국 코로나19 검역관련 통관 및 물류 애로사항 조사결과
# [2022.03.10] 글로벌 공급망 인사이트 2호
# 신남방지역 주요 이슈리포트(2022년 3월 10일)
# 2022년 2월 글로벌 및 주요국 경제동향과 전망
# [EU 경제통상 리포트(EU22-7)] EU의 對러시아 제재동향과 영향평가
# [EU 경제통상 리포트(EU22-6)] EU 기업 공급망 실사법안 초안 발표
# [EU 경제통상 리포트(EU22-5)] 유럽의회 환경위, EU 친환경 배터리 규정 법안 채택
# [EU 경제통상 리포트(EU22-4)] EU 녹색분류체계(Taxonomy) 위임입법 발표
# 2022 바이든 대통령 국정연설(3.1) 주요 내용
# [미국 경제통상 리포트(US22-6)] 美 상무부의 對러시아 수출관리규정 개정내용 및 현지 반응
# 2021년 우리나라의 전자상거래 수출동향
# EU, 러시아 은행 7곳 대상 SWIFT 퇴출 제재 발효
# 동남아대양주 코로나 재확산 및 방역 동향
# [2022.03.03] 글로벌 공급망 인사이트 1호
# 신남방지역 주요 이슈리포트(2022년 3월 3일)
# 미국의 대러 제재 49개 기업-기관 리스트
# [미국 경제통상 리포트(US22-5)] 2021년 미국 수출입 현황 분석 및 시사점
# EU의 우크라이나 사태 대응 현황과 경제 영향 전망
# 우크라이나 사태 : 미국의 대응과 향후 경제 영향 전망
# 신남방지역 주요 이슈리포트(2022년 2월 24일)
# [미국 경제통상 리포트(US22-4)] 미-EU 미-일본 철강 관세 면제 합의 내용 및 시사점
# 신남방지역 주요 이슈리포트(2022년 2월 17일)
# [미국 경제통상 리포트(US22-3)] 美 '21년 GDP 분석 및 '22년 GDP 전망
# [미국 경제통상 리포트(US22-2)] 바이든 정부 ‘인도-태평양 경제 프레임워크’ 추진 경과 및 전망
# 신남방지역 주요 이슈리포트(2022년 2월 10일)
# 2022년 1월 글로벌 및 주요국 경제동향과 전망
# [미국 경제통상 리포트(US22-1)] 미리 보는 2022년 미국 의회 이슈
# [EU 경제통상 리포트(EU22-3)] 탄소국경조정 유럽의회 환경위 법안 주요내용
# [EU 경제통상 리포트(EU22-2)] EU 에너지보조금 가이드라인 개정
# [EU 경제통상 리포트(EU22-1)] 2022년 유럽연합 주요정책 추진 전망
# 이탈리아 대선(1.29) 결과 및 향후 전망
# '21년 베트남의 경제실적과 무역동향 분석
# 신남방지역 주요 이슈리포트(2022년 2월 3일)
# 나이지리아 E나이라 도입 개요 및 향후 전망
# 신남방지역 주요 이슈리포트(2022년 1월 20일)
# 베이징올림픽으로 가속화된 중국 디지털 위안화 도입 동향
# 2021년 중국 경제지표 평가 및 전망
# 일본 경제안전보장추진법 주요 내용 및 시사점
# 최근 엔저가 일본경제에 미치는 영향 및 향후 전망
# 사우디 Jeddah Central Project 주요 내용 및 시사점
# 2021년 12월 글로벌 및 주요국 경제동향과 전망
# [EU 경제통상 리포트(EU21-6)] EU 글로벌 게이트웨이 주요내용
# [미국 경제통상 리포트(US21-8)] 미국의 주요 산업 정책 내용 및 현지 반응
# 신남방지역 주요 이슈리포트(2021년 12월 30일)
# 미얀마 中국경무역 위안화 결제 허용 동향
# 2022년 중국 경제전망 및 시사점
# 2022년 일본경제 주요 이슈 및 경제전망
# [EU 경제통상 리포트(EU21-5)] EU, 역외국 통상위협 대응(Anti-coercion) 규정안 발표
# [미국 경제통상 리포트(US21-7)] 월스트리트 주요 기관의 2022년 美 경제 전망과 위기 요인
# 신남방지역 주요 이슈리포트(2021년 12월 23일)
# 중국 산업그린화 14.5계획 추진 동향
# 최근 중국 위안화 환율 강세 및 향후 전망
# 대만 국민투표(12.18) 관련 현지 동향
# 신남방지역 주요 이슈리포트(2021년 12월 16일)
# 중국 중앙경제공작회의(12.8~10) 주요 내용 및 평가
# [미국 경제통상 리포트(US21-6)] 1.75조 달러 인적 인프라 투자법안 동향 및 전망
# 헝다 등 중국 부동산기업 디폴트위기 동향
# 신남방지역 주요 이슈리포트(2021년 12월 9일)
# 독일. 중도진보 성향의 신정부 출범
# [미국 경제통상 리포트(US21-5)] 코로나19 신종변이 오미크론이 미치는 경제 여파 및 시사점
# 2021년 11월 글로벌 및 주요국 경제동향과 전망
# [EU 경제통상 리포트(EU21-3)] OECD 다국적기업 법인세제 합의 결과 및 향후 전망
# 신남방지역 주요 이슈리포트(2021년 12월 2일)
# 신남방지역 주요 이슈리포트(2021년 11월 25일)
# [미국 경제통상 리포트(US21-4)] 온라인 플랫폼을 통한 美 조달참여 기회분석
# [미국 경제통상 리포트(US21-3)] 美 3.5조 법안내 친환경 및 미국산 특혜 조항 주요내용
# [미국 경제통상 리포트(US21-2)] 美 SEC, 기후변화 리스크 공시 의무화 동향
# [미국 경제통상 리포트(US21-1)] 美 ITC, The Year in Trade 2020 주요내용 및 시사점
# [EU 경제통상 리포트(EU21-2)] EU의 에너지 가격 급등 대응현황 및 시사점
# [EU 경제통상 리포트(EU21-1)] EU 공급망 실사 법안 추진 현황
# 신남방지역 주요 이슈리포트(2021년 11월 11일)
# 러시아의 요소 생산 수출 및 수출쿼터제 실시 동향
# 11월 미국 FOMC 회의 주요 결정사항 및 시장 반응
# 이라크 조기 총선 결과 및 향후 전망
# 2021년 10월 글로벌 및 주요국 경제동향과 전망
# 신남방지역 주요 이슈리포트(2021년 11월 4일)
# 신남방지역 주요 이슈리포트(2021년 10월 28일)
# 신남방지역 주요 이슈리포트(2021년 10월 21일)
# 중국 전력공급난 동향 및 전망
# 미국 항만 물류적체 현상 심화 관련 현지 물류전문가 인터뷰 결과
# 미국 의회 주요 쟁점법안 입법 동향 및 향후 전망
# 신남방지역 주요 이슈 리포트(2021년 10월 14일)
# 한-싱 간 입국 시 격리면제 합의 및 현지 동향
# 인도 석탄 수급 및 발전 전력 동향
# 2021년 9월 글로벌 및 주요국 경제동향과 전망
# 신남방지역 주요 이슈 리포트(2021년 10월 7일)
# 日 기시다 新수상 선출 선거 결과 및 주요 정책
# 신남방지역 주요 이슈 리포트(2021년 9월 30일)
# 중국 전력공급난에 따른 진출기업 동향
# 일본의 희소금속 안정적 공급 확보 전략과 시사점
# 포스트 메르켈 시대. 독일 총선(9.26.) 결과 및 향후 전망
# 9월 미국 FOMC 회의 주요 결정사항 및 향후 전망
# EU 집행위원장 연례 국정연설 주요내용
# 중국 헝다그룹 유동성 위기 동향
# 신남방지역 주요 이슈 리포트(2021년 9월 16일)
# 신남방지역 주요 이슈 리포트(2021년 9월 9일)
# 신남방 지역 코로나 확산 동향 및 현지 기업환경 동향
# 코로나19로 인한 글로벌 및 주요국 경제동향과 전망(2021년 8월)
# 美 정부 발표 바이 아메리칸 개정안 주요내용
# 신남방지역 주요 이슈 리포트(2021년 9월 2일)
# 신남방지역 주요 이슈 리포트(2021년 8월 25일)
# 2021년 하반기 중국 경제전망 및 시사점
# 미국 인프라 투자법안 주요 내용 및 시사점
# 신남방지역 주요 이슈 리포트(2021년 8월 18일)
# 신남방지역 주요 이슈 리포트(2021년 8월 12일)
# 신남방지역 주요 이슈 리포트(2021년 8월 5일)
# 신남방지역 주요 이슈 리포트('21.9.29~8.4)
# 중국 상반기 경제지표 평가와 전망
# 중국 6월 및 상반기 수출입 동향 및 전망
# EU 탄소국경조정제도(CBAM) 규정안 주요내용 요약
# 중국 1~5월 신에너지 승용차 판매 급증과 시사점
# 中 공산당 창당 100주년 시진핑 연설 주요 내용
# 美 공급망 검토 주요내용 및 향후전망
# 美 정부 자국산 우대 조달 정책 추진동향
# 美 상원 통과 미국혁신경쟁법안 주요내용 요약
# G20 경제현황 및 전망
# 중국 제7차 인구센서스 결과 발표
# 일본의 탄소 프라이싱 정책 추진과 전망
# 디지털위안화 시범운영 현황 및 주목할 유망산업
# 바이든 대통령 상하원 합동연설 요약
# 중국 통상정책 방향 전망 주요내용
# 글로벌 전기차 배터리 시장 동향 및 주요 이슈
# 사우디 지역본부유치(RHQ) 정책 주요내용 및 시사점
# 유럽 주요 자동차 제조사 전기차 전환 동향 및 전망
# 기후 정상회의 개최 결과 요약
# 중국 1분기 경제지표 평가
# 美 재무부 환율정책 보고서 발표 주요내용 요약
# 설문조사로 살펴본 2021년 아세안 주요 이슈 및 시사점
# 美 바이든 정부의 글로벌 최저법인세율 제안 및 전망
# 일본기업의 GVC 재구축 추진현황 및 대응사례
# 美정부 인프라 제조업 등 투자를 통한 경제재건 계획
# 미국 백신 공급 계획에 따른 경제 전망
# EU탄소국경조정제도 논의 동향과 추진전망
# 바이든 행정부 미국 최초로 환율 상계관세 부과 결정
# 코로나19 악화일로 브라질의 재확산 현황 및 전망
# 글로벌 희토류 산업동향 및 시사점
# 바이든 정부 기후변화대응 정책동향 및 전망
# 중국 1~2월 경제지표로 본 경기회복세 평가
# 中 양회를 통해 본 정책방향과 주목할 3대 산업
# 미국 EU정부의 미래산업 공급망 추진동향 보고
# 최근 중국의 세계교역 점유율 증가와 韓中 교역 관계 변화
# 2021 미국 통상정책 아젠다 요약보고
# 유럽 그린딜 주요 내용 및 시사점
# 일본 수소사회 구현을 위한 국제 수소GVC 구축
# 2021 중국 전국인민대표대회 정부업무보고
# `20년 베트남의 경제실적과 무역동향 분석
# 한-중미 FTA 전체발효 주요내용 및 수출유망 품목
# 미국 정부의 디지털 통상정책 수립관련 주요 이슈점검
# 전세계 반도체 부족 사태 관련 유럽 반도체 산업 동향
# 전세계 반도체 부족 사태 관련 미국 반도체 산업 동향 및 전망
# 베트남 13차 전당대회 주요 결과 및 시사점
# 지방양회로 본 2021 중국경제 8대 키워드
# 바이든 정부 바이아메리칸 정책 주요내용과 향후 전망
# 코로나19 방역모범국 대만의 '20년 경제성장과 시사점
# 바이든 행정부 경제통상정책 방향 현지전문가 의견
# 바이든 행정부, 기후변화 대응 행정명령 주요 내용 및 시사점
# 중국 희토류 생산 및 수출관리 강화 동향 및 영향 분석
# 바이든 정부 바이아메리칸 강화 행정명령 동향 및 시사점
# 일본의 리쇼어링 정책 변화 및 전망
# 2020년 중국 주요경제지표
# 2020년 중국 대외교역 현황 및 전망
# 미국 디지털 화폐 추진 동향 및 전망
# 중국 외국인투자 장려산업 목록 주요 내용과 평가 및 시사점
# 조지아 상원의원 선거 결과와 바이든 정부의 경제 정책 전망
# 295 건 저장완료..

# %% [markdown]
# ## reads the saved csv file and displays the result as a dataframe

# %%
document = db_select('경제_무역.db','경제_무역')

# %%
document
# Out:
#                                                   제목         카테고리        국가  \
# 0                   숫자로 보는 세계 70개 항구 적체 현황 리포트(9월 호)  글로벌 이슈 모니터링  KOTRA 본사
# 1              미국 국가 생명공학 및 바이오 제조 이니셔티브(9.12) 주요 내용  글로벌 이슈 모니터링        미국
# 2       [미국경제통상리포트(US22-32)]미국의 전기차 배터리용 핵심 광물 확보 전략  글로벌 이슈 모니터링        미국
# 3    [미국경제통상리포트(US22-31)] IPEF 9월 장관회의 세부 내용 및 현지 반응  글로벌 이슈 모니터링        미국
# 4                       인도 정부의 탄소배출 감축 계획과 우리기업 기회요인  글로벌 이슈 모니터링        인도
# ..                                               ...          ...       ...
# 290                                  2020년 중국 주요경제지표  글로벌 이슈 모니터링        중국
# 291                            2020년 중국 대외교역 현황 및 전망  글로벌 이슈 모니터링        중국
# 292                             미국 디지털 화폐 추진 동향 및 전망  글로벌 이슈 모니터링        미국
# 293                 중국 외국인투자 장려산업 목록 주요 내용과 평가 및 시사점  글로벌 이슈 모니터링        중국
# 294                 조지아 상원의원 선거 결과와 바이든 정부의 경제 정책 전망  글로벌 이슈 모니터링        미국
#
#                                                     본문
# 0    KOTRA는 A빅데이터를 기반으로 해상운송 정보를 제공하는 스타트업 씨벤티지SeaV...
# 1     바이든 대통령은 바이오 산업의 자국내 생산 강화를 골자로 하는국가 생명공학 및 바...
# 2     인플레이션 감축법으로 전기차EV 산업 재편 가속화 미국 내 EV 배터리 생산 확대...
# 3     이번 회의를 통해 합의된 PEF 4개 주요 의제의 세부 내용을 공개 무역 장벽 완...
# 4     배출 현황 美 다음으로 가장 많은 이산화탄소를 배출하는 세계 3위 탄소배출국 감축...
# ..                                                 ...
# 290  2020년 중국 주요경제지표 2020년 중국 경제성장률 23 GDP 총액 100조 ...
# 291  2020년 중국 대외교역 현황 및 전망 수출입 현황 20년 교역액 전년 대비 15 ...
# 292  미국 디지털 화폐 추진 동향 및 전망 최근 동향 연방정부 중국의 디지털 위안 도입 ...
# 293  중국 외국인투자 장려산업 목록 주요 내용과 평가 및 시사점 외국인투자 장려산업 목록...
# 294  조지아 상원의원 선거 결과와 바이든 정부의 경제 정책 전망 선거결과 높은 우편 투표...
#
# [295 rows x 4 columns]
